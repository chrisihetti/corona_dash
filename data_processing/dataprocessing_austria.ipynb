# %%
# Out:
#                             name  cases
# 0                      Amstetten    210
# 1                          Baden     96
# 2                        Bludenz    212
# 3                 Braunau am Inn     88
# 4                        Bregenz    199
# 5            Bruck an der Leitha     58
# 6             Bruck-Mürzzuschlag     43
# 7               Deutschlandsberg     30
# 8                       Dornbirn    122
# 9                       Eferding     38
# 10             Eisenstadt(Stadt)     12
# 11           Eisenstadt-Umgebung     17
# 12                     Feldkirch    189
# 13                   Feldkirchen      9
# 14                     Freistadt     98
# 15                   Gänserndorf     58
# 16                         Gmünd      6
# 17                       Gmunden     59
# 18                   Graz(Stadt)    343
# 19                 Graz-Umgebung    120
# 20                  Grieskirchen     60
# 21                      Gröbming     29
# ...

# %%
#https://data.statistik.gv.at/web/meta.jsp?dataset=OGDEXT_POLBEZ_1

# %%
pd.set_option('display.max_rows',500)
pd.set_option('display.max_columns',500)
gdf
# Out:
#       id                           name  \
# 0    101              Eisenstadt(Stadt)
# 1    102                    Rust(Stadt)
# 2    103            Eisenstadt-Umgebung
# 3    104                        Güssing
# 4    105                    Jennersdorf
# 5    106                    Mattersburg
# 6    107                Neusiedl am See
# 7    108                 Oberpullendorf
# 8    109                       Oberwart
# 9    201               Klagenfurt Stadt
# 10   202                  Villach Stadt
# 11   203                       Hermagor
# 12   204                Klagenfurt Land
# 13   205         Sankt Veit an der Glan
# 14   206            Spittal an der Drau
# 15   207                   Villach Land
# 16   208                    Völkermarkt
# 17   209                      Wolfsberg
# 18   210                    Feldkirchen
# 19   301      Krems an der Donau(Stadt)
# 20   302            Sankt Pölten(Stadt)
# 21   303   Waidhofen an der Ybbs(Stadt)
# ...
